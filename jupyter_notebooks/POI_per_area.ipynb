# %%
import pandas as pd
from sql import engine #adjust this as necessary to match your sql.py connection methods
import psycopg2

# %%
df = pd.read_csv('/Users/evo/Documents/neue_fische/capstone_final/csv/Places.csv')

# %%
df
# Out:
#       Unnamed: 0                                            name  \
# 0              0                       Berlin Ruppiner Chaussee.
# 1              1                                            Aral
# 2              2                    Pro D.Systemdienstleistungen
# 3              3                                           Shell
# 4              4                 Berlin Hermsdorfer Damm 141-143
# ...          ...                                             ...
# 2675         610              VW Fs Rent-a-Car-Trudering München
# 2676         611  Sixt Auto-und Transportervermietung Neuperlach
# 2677         612               MAHAG Automobilhandel und Service
# 2678         613                            Avesa Autovermietung
# 2679         614                           Re-Car Autovermietung
#
#                                        address  postcode  latitude  longitude  \
# 0          Ruppiner Chaussee 339, 13503 Berlin     13503  52.62073   13.23623
# ...

# %%
df2 = pd.read_csv('/Users/evo/Documents/neue_fische/capstone_final/csv/city_cars.csv')

df2
# Out:
#   registration district  passenger car  total population above 18  \
# 0              muenchen         732045                    1248456
# 1                berlin        1234645                    3063617
# 2               hamburg         805780                    1536367
# 3     frankfurt am main         342431                     633992
# 4                 koeln         492402                     912527
#
#    age 18 - 24  age 25 - 34  age 35 - 44  age 45 - 54  age 55 - 64  \
# 0       119731       275743       221506       205658       166733
# 1       264084       613696       530715       482906       466691
# 2       146312       301802       266363       261156       224375
# 3        58178       137963       120998       110428        87402
# 4        92243       186045       154761       156601       133456
#
#    age 65 - 74  age above 75  cars per capita  income per capita   latitude  \
# 0       119222        139863         0.586360             32.766  48.137154
# ...

# %%
# create the filter
df_hamburg_carwash = df.query(" city == 'hamburg' and category == 'car wash'")
df_hamburg_gasstation = df.query("city == 'hamburg' and category == 'gas station'")
df_hamburg_carretail = df.query("city == 'hamburg' and category == 'car retailer'")
df_hamburg_rental = df.query("city == 'hamburg' and category == 'car rental'")

# count the categories
hamburg_carwash_count = df_hamburg_carwash['category'].count()
hamburg_gasstation_count = df_hamburg_gasstation['category'].count()
hamburg_carretail_count = df_hamburg_carretail['category'].count()
hamburg_rental_count = df_hamburg_rental['category'].count()

# calculation poi per area
hh_carwash_per_area = hamburg_carwash_count/794.624370
hh_gasstation_per_area = hamburg_gasstation_count/794.624370
hh_carretail_per_area = hamburg_carretail_count/794.624370
hh_rental_per_area = hamburg_rental_count/794.624370

# calculation how many carwash per how many kilometers
many_carwash_per_km_hh = 1/hh_carwash_per_area
many_gasstation_per_km_hh = 1/hh_gasstation_per_area
many_carretail_per_km_hh = 1/hh_carretail_per_area
many_rental_per_km_hh = 1/hh_rental_per_area

# %%
df_berlin_carwash = df.query(" city == 'berlin' and category == 'car wash'")
df_berlin_gasstation = df.query("city == 'berlin' and category == 'gas station'")
df_berlin_carretail = df.query("city == 'berlin' and category == 'car retailer'")
df_berlin_rental = df.query("city == 'berlin' and category == 'car rental'")


berlin_carwash_count = df_berlin_carwash['category'].count()
berlin_gasstation_count = df_berlin_gasstation['category'].count()
berlin_carretail_count = df_berlin_carretail['category'].count()
berlin_rental_count = df_berlin_rental['category'].count()

b_carwash_per_area = berlin_carwash_count/889.412893	
b_gasstation_per_area = berlin_gasstation_count/889.412893	
b_carretail_per_area = berlin_carretail_count/889.412893	
b_rental_per_area = berlin_rental_count/889.412893	


many_carwash_per_km_b = 1/b_carwash_per_area
many_gasstation_per_km_b = 1/b_gasstation_per_area
many_carretail_per_km_b = 1/b_carretail_per_area
many_rental_per_km_b = 1/b_rental_per_area

# %%
df_koeln_carwash = df.query(" city == 'koeln' and category == 'car wash'")
df_koeln_gasstation = df.query("city == 'koeln' and category == 'gas station'")
df_koeln_carretail = df.query("city == 'koeln' and category == 'car retailer'")
df_koeln_rental = df.query("city == 'koeln' and category == 'car rental'")

koeln_carwash_count = df_koeln_carwash['category'].count()
koeln_gasstation_count = df_koeln_gasstation['category'].count()
koeln_carretail_count = df_koeln_carretail['category'].count()
koeln_rental_count = df_koeln_rental['category'].count()

k_carwash_per_area = koeln_carwash_count/404.856749		
k_gasstation_per_area = koeln_gasstation_count/404.856749		
k_carretail_per_area = koeln_carretail_count/404.856749		
k_rental_per_area = koeln_rental_count/404.856749	

many_carwash_per_km_k = 1/k_carwash_per_area
many_gasstation_per_km_k = 1/k_gasstation_per_area
many_carretail_per_km_k = 1/k_carretail_per_area
many_rental_per_km_k = 1/k_rental_per_area

# %%
df_muenchen_carwash = df.query(" city == 'muenchen' and category == 'car wash'")
df_muenchen_gasstation = df.query("city == 'muenchen' and category == 'gas station'")
df_muenchen_carretail = df.query("city == 'muenchen' and category == 'car retailer'")
df_muenchen_rental = df.query("city == 'muenchen' and category == 'car rental'")

muenchen_carwash_count = df_muenchen_carwash['category'].count()
muenchen_gasstation_count = df_muenchen_gasstation['category'].count()
muenchen_carretail_count = df_muenchen_carretail['category'].count()
muenchen_rental_count = df_muenchen_rental['category'].count()

m_carwash_per_area = muenchen_carwash_count/310.904727			
m_gasstation_per_area = muenchen_gasstation_count/310.904727			
m_carretail_per_area = muenchen_carretail_count/310.904727			
m_rental_per_area = muenchen_rental_count/310.904727	

many_carwash_per_km_m = 1/m_carwash_per_area
many_gasstation_per_km_m = 1/m_gasstation_per_area
many_carretail_per_km_m = 1/m_carretail_per_area
many_rental_per_km_m = 1/m_rental_per_area

# %%
df_frankfurt_am_main_carwash = df.query(" city == 'frankfurt am main' and category == 'car wash'")
df_frankfurt_am_main_gasstation = df.query("city == 'frankfurt am main' and category == 'gas station'")
df_frankfurt_am_main_carretail = df.query("city == 'frankfurt am main' and category == 'car retailer'")
df_frankfurt_am_main_rental = df.query("city == 'frankfurt am main' and category == 'car rental'")

frankfurt_am_main_carwash_count = df_frankfurt_am_main_carwash['category'].count()
frankfurt_am_main_gasstation_count = df_frankfurt_am_main_gasstation['category'].count()
frankfurt_am_main_carretail_count = df_frankfurt_am_main_carretail['category'].count()
frankfurt_am_main_rental_count = df_frankfurt_am_main_rental['category'].count()

f_carwash_per_area = frankfurt_am_main_carwash_count/248.407973			
f_gasstation_per_area = frankfurt_am_main_gasstation_count/248.407973			
f_carretail_per_area = frankfurt_am_main_carretail_count/248.407973			
f_rental_per_area = frankfurt_am_main_rental_count/248.407973	

many_carwash_per_km_f = 1/f_carwash_per_area
many_gasstation_per_km_f = 1/f_gasstation_per_area
many_carretail_per_km_f = 1/f_carretail_per_area
many_rental_per_km_f = 1/f_rental_per_area

# %%
df_hamburg_carwash
# Out:
#      Unnamed: 0                           name  \
# 165         165                           Aral
# 166         166                           Aral
# 167         167  Clean Park Sb Autowaschanlage
# 168         168                           Aral
# 169         169           Angela Gitta Schäfer
# ..          ...                            ...
# 285         285                        Nordoel
# 286         286   Hamburg Kirchwerder Landweg.
# 287         287                Avia Tankstelle
# 288         288                           Aral
# 289         289                           Aral
#
#                                       address  postcode  latitude  longitude  \
# 165     Holsteiner Chaussee 55, 22523 Hamburg     22523  53.61434    9.90589
# 166       Schleswiger Damm 173, 22457 Hamburg     22457  53.64134    9.91696
# 167     Holsteiner Chaussee 85, 22523 Hamburg     22523  53.61646    9.90683
# 168     Pinneberger Straße 1-3, 22457 Hamburg     22457  53.63252    9.91008
# ...

# %%
poi_per_area = pd.DataFrame(columns = ['city', 'carwash_count',"carwash_per_area","carwash_per_km",'gasstation_count',"gasstation_per_area","gasstation_per_km","carretail_count","carretail_per_area","carretail_per_km",'rental_count',"rental_per_area", 'rental_per_km', 'lat', 'lon',"country"])

# %%
poi_per_area
# Out:
# Empty DataFrame
# Columns: [city, carwash_count, carwash_per_area, carwash_per_km, gasstation_count, gasstation_per_area, gasstation_per_km, carretail_count, carretail_per_area, carretail_per_km, rental_count, rental_per_area, rental_per_km, lat, lon, country]
# Index: []

# %%
poi_per_area['country'] = ['Deutschland', 'Deutschland', 'Deutschland', 'Deutschland', 'Deutschland',]
poi_per_area['city'] = ['hamburg', 'muenchen', 'koeln', 'frankfurt am main', 'berlin']
poi_per_area["carwash_count"] = [hamburg_carwash_count,muenchen_carwash_count,koeln_carwash_count,frankfurt_am_main_carwash_count,berlin_carwash_count]
poi_per_area["carwash_per_area"] = [hh_carwash_per_area,m_carwash_per_area,k_carwash_per_area,f_carwash_per_area,b_carwash_per_area]
poi_per_area["carwash_per_km"] = [many_carwash_per_km_hh,many_carwash_per_km_m,many_carwash_per_km_k,many_carwash_per_km_f,many_carwash_per_km_b]
poi_per_area["gasstation_count"] = [hamburg_gasstation_count,muenchen_gasstation_count,koeln_gasstation_count,frankfurt_am_main_gasstation_count,berlin_gasstation_count]
poi_per_area["gasstation_per_area"] = [hh_gasstation_per_area,m_gasstation_per_area,k_gasstation_per_area,f_gasstation_per_area,b_gasstation_per_area]
poi_per_area["gasstation_per_km"] = [many_gasstation_per_km_hh,many_gasstation_per_km_m,many_gasstation_per_km_k,many_gasstation_per_km_f,many_gasstation_per_km_b]
poi_per_area["carretail_count"] = [hamburg_carretail_count,muenchen_carretail_count,koeln_carretail_count,frankfurt_am_main_carretail_count,berlin_carretail_count]
poi_per_area["carretail_per_area"] = [hh_carretail_per_area,m_carretail_per_area,k_carretail_per_area,f_carretail_per_area,b_carretail_per_area]
poi_per_area["carretail_per_km"] = [many_carretail_per_km_hh,many_carretail_per_km_m,many_carretail_per_km_k,many_carretail_per_km_f,many_carretail_per_km_b]
poi_per_area["rental_count"] = [hamburg_rental_count,muenchen_rental_count,koeln_rental_count,frankfurt_am_main_rental_count,berlin_rental_count]
poi_per_area["rental_per_area"] = [hh_rental_per_area,m_rental_per_area,k_rental_per_area,f_rental_per_area,b_rental_per_area]
poi_per_area["rental_per_km"] = [many_rental_per_km_hh,many_rental_per_km_m,many_rental_per_km_k,many_rental_per_km_f,many_rental_per_km_b]
poi_per_area['lat'] = [53.550556, 48.137154, 50.936389, 50.116667, 52.518611]
poi_per_area['lon']= [9.993333, 11.576124, 6.952778, 8.683333, 13.408333]

# %%
poi_per_area
# Out:
#                 city  carwash_count  carwash_per_area  carwash_per_km  \
# 0            hamburg            125          0.157307        6.356995
# 1           muenchen             69          0.221933        4.505866
# 2              koeln             43          0.106210        9.415273
# 3  frankfurt am main             42          0.169077        5.914476
# 4             berlin            165          0.185516        5.390381
#
#    gasstation_count  gasstation_per_area  gasstation_per_km  carretail_count  \
# 0               266             0.334749           2.987310              122
# 1               168             0.540358           1.850623               81
# 2               142             0.350741           2.851104               86
# 3                87             0.350230           2.855264               71
# 4               373             0.419378           2.384485              225
#
#    carretail_per_area  carretail_per_km  rental_count  rental_per_area  \
# ...

# %%
# Export to csv
poi_per_area.to_csv('/Users/evo/Documents/neue_fische/capstone_final/csv/poi_per_area.csv', index=False)
